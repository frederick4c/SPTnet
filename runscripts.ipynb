# %% [markdown]
# # Running SPTnet Scripts for Colab

# %% [markdown]
# ## Setup

# %% [markdown]
# ### Import Git Repo

# %%
# !git clone https://github.com/frederick4c/SPTnet.git
# %cd SPTnet
# Out:
# Cloning into 'SPTnet'...
# remote: Enumerating objects: 423, done.
# remote: Counting objects: 100% (60/60), done.
# remote: Compressing objects: 100% (44/44), done.
# remote: Total 423 (delta 47), reused 25 (delta 16), pack-reused 363 (from 2)
# Receiving objects: 100% (423/423), 6.58 MiB | 13.66 MiB/s, done.
# Resolving deltas: 100% (185/185), done.
# Filtering content: 100% (9/9), 442.04 MiB | 35.13 MiB/s, done.
# /content/SPTnet/SPTnet/SPTnet/SPTnet/SPTnet

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ### Install environment/dependencies

# %%
# !pip install -q condacolab
import condacolab
condacolab.install_miniforge()
# Out:
# ⏬ Downloading https://github.com/jaimergp/miniforge/releases/download/24.11.2-1_colab/Miniforge3-colab-24.11.2-1_colab-Linux-x86_64.sh...
# 📦 Installing...
# 📌 Adjusting configuration...
# 🩹 Patching environment...
# ⏲ Done in 0:00:08
# 🔁 Restarting kernel...
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
# %cd SPTnet
# %ls
# Out:
# [Errno 2] No such file or directory: 'SPTnet'
# /content/SPTnet/SPTnet/SPTnet/SPTnet/SPTnet
#  compute_CRLB_matrix.m              SPTnet_inference.py
#  CRLB_H_D_frame.mat                 SPTnet_toolbox.py
#  Example_workflow_1/                SPTnet_training_colab.py
# 'Installation of SPTnet.pdf'        SPTnet_trainingdata_generator.m
#  LICENSE                            SPTnet_training.py
#  mat_to_tiff.py                    'SPTnet user manual.pdf'
# 'Package required for SPTnet.txt'   TestData/
#  PSF-toolbox/                       Trained_models/
#  __pycache__/                       transformer3d.py
#  README.md                          transformer.py
#  runscripts.ipynb                   Visualize_SPTnet_Outputs_GUI.m
#  Segementation/                     Visualize_SPTnet_Outputs.m
#  SPTnet_environment.yml

# %%
# !mamba env update -n SPTnet -f SPTnet_environment.yml
# Out:
# Channels:
#  - defaults
#  - conda-forge
# Platform: linux-64
# ...
# Solving environment: done
#
#
# ==> WARNING: A newer version of conda exists. <==
#     current version: 24.11.2
#     latest version: 26.1.0
#
# Please update conda by running
#
#     $ conda update -n base -c conda-forge conda
#
#
#
# ...
# libllvm15-15.0.7     | 35.4 MB   | :   0% 0/1 [00:00<?, ?it/s]
# pillow-12.1.0        | 35.0 MB   | :   0% 0/1 [00:00<?, ?it/s]
#
# icu-73.1             | 25.9 MB   | :   0% 0/1 [00:00<?, ?it/s]
#
#
# python-3.10.19       | 24.5 MB   | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
# scipy-1.15.3         | 21.2 MB   | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
# qtdeclarative-6.9.2  | 16.7 MB   | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
# pandas-2.3.3         | 11.8 MB   | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
# qtbase-6.9.2         | 11.4 MB   | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
# mpich-4.3.2          | 11.0 MB   | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
# ...

# %%
import sys

# Add the specific directory where your package was found
pkg_path = '/usr/local/lib/python3.11/site-packages'
if pkg_path not in sys.path:
    sys.path.insert(0, pkg_path)

# %%
# !mamba init
# !mamba activate SPTnet
# Out:
# no change     /usr/local/condabin/conda
# no change     /usr/local/bin/conda
# no change     /usr/local/bin/conda-env
# no change     /usr/local/bin/activate
# no change     /usr/local/bin/deactivate
# no change     /usr/local/etc/profile.d/conda.sh
# no change     /usr/local/etc/fish/conf.d/conda.fish
# no change     /usr/local/shell/condabin/Conda.psm1
# no change     /usr/local/shell/condabin/conda-hook.ps1
# no change     /usr/local/lib/python3.11/site-packages/xontrib/conda.xsh
# no change     /usr/local/etc/profile.d/conda.csh
# modified      /root/.bashrc
#
# ==> For changes to take effect, close and re-open your current shell. <==
#
# WARNING conda.common.path.windows:_path_to(100): cygpath is not available, fallback to manual path conversion
# WARNING conda.common.path.windows:_path_to(100): cygpath is not available, fallback to manual path conversion
# Added mamba to /root/.bashrc
#
# ==> For changes to take effect, close and re-open your current shell. <==
#
# ...

# %% [markdown]
# ## Train

# %% [markdown]
# ### Run Training Script

# %%
# !pip install matplotlib
# !mamba run -n SPTnet python SPTnet_training_colab.py --model-dir /content/drive/MyDrive/SPTnet/test_run --data TestData/eg_trainingvideos_*.mat
# Out:
# Model will be saved to: /content/SPTnet/SPTnet/SPTnet/SPTnet/SPTnet/Trained_models/trained_model
# ✅ Write check passed: Output directory is writable.
# Loading training data from 5 files...
# Processing file 1/5: TestData/eg_trainingvideos_1.mat
# Processing file 2/5: TestData/eg_trainingvideos_2.mat
# Processing file 3/5: TestData/eg_trainingvideos_3.mat
# Processing file 4/5: TestData/eg_trainingvideos_4.mat
# Processing file 5/5: TestData/eg_trainingvideos_5.mat
# Data loading complete. Total samples: 500
# Initializing model...
# Starting Epoch 1...
# Finished validation for Epoch 1. Loss: 2.3903
# ==> Saving a new best model
# learning rate is: 0.000100
# (epoch 1 ) Training Loss 2.4504328419819164 Validation Loss 2.3903205125348954
# Starting Epoch 2...
# Finished validation for Epoch 2. Loss: 2.3113
# ==> Saving a new best model
# learning rate is: 0.000100
# (epoch 2 ) Training Loss 2.3085055357974174 Validation Loss 2.3113417014646327
# Starting Epoch 3...
# ...

# %%
# %ls
# Out:
#  compute_CRLB_matrix.m              SPTnet_inference.py
#  CRLB_H_D_frame.mat                 SPTnet_toolbox.py
#  Example_workflow_1/                SPTnet_training_colab.py
# 'Installation of SPTnet.pdf'        SPTnet_trainingdata_generator.m
#  LICENSE                            SPTnet_training.py
#  mat_to_tiff.py                    'SPTnet user manual.pdf'
# 'Package required for SPTnet.txt'   TestData/
#  PSF-toolbox/                       Trained_models/
#  __pycache__/                       transformer3d.py
#  README.md                          transformer.py
#  runscripts.ipynb                   Visualize_SPTnet_Outputs_GUI.m
#  Segementation/                     Visualize_SPTnet_Outputs.m
#  SPTnet_environment.yml

# %% [markdown]
# ### Copy result to Google Drive
# Then copy into git repository

# %%
# !cp -r "Trained_models" "/content/drive/MyDrive/SPTnet/"

# %% [markdown]
# ## Inference

# %%
# !mamba run -n base python SPTnet_inference_colab.py \
  --model-path "Trained_models/trained_model"  \
  --data "TestData/tiff_output.tif" "TestData/Example_testdata.mat"
