# %% [markdown]
# # Running SPTnet Scripts for Colab

# %% [markdown]
# Import Git Repo

# %%
# !git clone https://github.com/frederick4c/SPTnet.git
# %cd SPTnet
# Out:
# Cloning into 'SPTnet'...
# remote: Enumerating objects: 397, done.
# remote: Counting objects: 100% (220/220), done.
# remote: Compressing objects: 100% (197/197), done.
# remote: Total 397 (delta 116), reused 63 (delta 19), pack-reused 177 (from 2)
# Receiving objects: 100% (397/397), 6.54 MiB | 14.15 MiB/s, done.
# Resolving deltas: 100% (170/170), done.s:  49% (84/170)
# Filtering content: 100% (9/9), 442.04 MiB | 51.93 MiB/s, done.
# /content/SPTnet

# %% [markdown]
# Install environment/dependencies

# %%
# !pip install -q condacolab
import condacolab
condacolab.install_miniforge()
# Out:
# ⏬ Downloading https://github.com/jaimergp/miniforge/releases/download/24.11.2-1_colab/Miniforge3-colab-24.11.2-1_colab-Linux-x86_64.sh...
# 📦 Installing...
# 📌 Adjusting configuration...
# 🩹 Patching environment...
# ⏲ Done in 0:00:07
# 🔁 Restarting kernel...
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
# !mamba env update -n base -f SPTnet_environment.yml
# Out:
# Channels:
#  - defaults
#  - conda-forge
# Platform: linux-64
# Collecting package metadata (repodata.json): done
# Solving environment: failed
#
# SpecsConfigurationConflictError: Requested specs conflict with configured specs.
#   requested specs:
#     - h5py
#     - ipython
#     - matplotlib
#     - pandas
#     - pip
#     - python=3.10
#     - scipy
#     - tifffile
#     - tqdm
#   pinned specs:
#     - cudatoolkit=*.*
#     - python=3.12
#     - python_abi=3.12[build=*cp312*]
# Use 'conda config --show-sources' to look for 'pinned_specs' and 'track_features'
# configuration parameters.  Pinned specs may also be defined in the file
# /usr/local/conda-meta/pinned.

# %%
# %cd SPTnet
# %ls
# Out:
# [Errno 2] No such file or directory: 'SPTnet'
# /content/SPTnet
#  compute_CRLB_matrix.m              Segementation/
#  condacolab_install.log             SPTnet_environment.yml
#  CRLB_H_D_frame.mat                 SPTnet_inference.py
# 'Example testdata'/                 SPTnet_toolbox.py
#  Example_workflow_1/                SPTnet_trainingdata_generator.m
# 'Installation of SPTnet.pdf'        SPTnet_training.py
#  LICENSE                           'SPTnet user manual.pdf'
#  mat_to_tiff.py                    'Trained models'/
# 'Package required for SPTnet.txt'   transformer3d.py
#  PSF-toolbox/                       transformer.py
#  __pycache__/                       Visualize_SPTnet_Outputs_GUI.m
#  README.md                          Visualize_SPTnet_Outputs.m
#  runscripts.ipynb

# %%
import sys

# Add the specific directory where your package was found
pkg_path = '/usr/local/lib/python3.11/site-packages'
if pkg_path not in sys.path:
    sys.path.insert(0, pkg_path)

# %%
# !python SPTnet_training_colab.py --model-dir ./my_model_output --data ./my_training_data/*.mat
# Out:
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/site-packages (3.10.8)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/site-packages (from matplotlib) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/site-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: numpy>=1.23 in /usr/local/lib/python3.11/site-packages (from matplotlib) (2.4.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/site-packages (from matplotlib) (24.2)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/site-packages (from matplotlib) (12.1.0)
# Requirement already satisfied: pyparsing>=3 in /usr/local/lib/python3.11/site-packages (from matplotlib) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# python: can't open file '/content/SPTnet/SPTnet_training_colab.py': [Errno 2] No such file or directory

# %%
import sys

# Add the specific directory where your package was found
pkg_path = '/usr/local/lib/python3.11/site-packages'
if pkg_path not in sys.path:
    sys.path.insert(0, pkg_path)

# Now try the import again
from positional_encodings.torch_encodings import PositionalEncodingPermute1D, PositionalEncodingPermute2D, PositionalEncodingPermute3D, Summer
print("Imports worked!")
# Out:
# Imports worked!

# %%
# !pip install positional-encodings
# Out:
# Requirement already satisfied: positional-encodings in /usr/local/lib/python3.11/site-packages (6.0.3)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/site-packages (from positional-encodings) (2.4.2)
