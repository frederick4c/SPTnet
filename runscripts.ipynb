# %% [markdown]
# # Running SPTnet Scripts for Colab

# %% [markdown]
# Import Git Repo

# %%
# !git clone https://github.com/frederick4c/SPTnet.git
# %cd SPTnet
# Out:
# Cloning into 'SPTnet'...
# remote: Enumerating objects: 402, done.
# remote: Counting objects: 100% (225/225), done.
# remote: Compressing objects: 100% (200/200), done.
# remote: Total 402 (delta 119), reused 68 (delta 21), pack-reused 177 (from 2)
# Receiving objects: 100% (402/402), 6.54 MiB | 14.31 MiB/s, done.
# Resolving deltas: 100% (173/173), done.
# Filtering content: 100% (9/9), 442.04 MiB | 66.60 MiB/s, done.
# /content/SPTnet/SPTnet

# %% [markdown]
# Install environment/dependencies

# %%
# !pip install -q condacolab
import condacolab
condacolab.install_miniforge()
# Out:
# ⏬ Downloading https://github.com/jaimergp/miniforge/releases/download/24.11.2-1_colab/Miniforge3-colab-24.11.2-1_colab-Linux-x86_64.sh...
# 📦 Installing...
# 📌 Adjusting configuration...
# 🩹 Patching environment...
# ⏲ Done in 0:00:07
# 🔁 Restarting kernel...
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
# !mamba env update -n base -f SPTnet_environment.yml
# Out:
# Channels:
#  - defaults
#  - conda-forge
# Platform: linux-64
# Collecting package metadata (repodata.json): done
# Solving environment: failed
#
# SpecsConfigurationConflictError: Requested specs conflict with configured specs.
#   requested specs:
#     - h5py
#     - ipython
#     - matplotlib
#     - pandas
#     - pip
#     - python=3.10
#     - scipy
#     - tifffile
#     - tqdm
#   pinned specs:
#     - cudatoolkit=*.*
#     - python=3.12
#     - python_abi=3.12[build=*cp312*]
# Use 'conda config --show-sources' to look for 'pinned_specs' and 'track_features'
# configuration parameters.  Pinned specs may also be defined in the file
# /usr/local/conda-meta/pinned.

# %%
# %cd SPTnet
# %ls
# Out:
# [Errno 2] No such file or directory: 'SPTnet'
# /content/SPTnet/SPTnet
#  compute_CRLB_matrix.m              SPTnet_environment.yml
#  CRLB_H_D_frame.mat                 SPTnet_inference.py
# 'Example testdata'/                 SPTnet_toolbox.py
#  Example_workflow_1/                SPTnet_training_colab.py
# 'Installation of SPTnet.pdf'        SPTnet_trainingdata_generator.m
#  LICENSE                            SPTnet_training.py
#  mat_to_tiff.py                    'SPTnet user manual.pdf'
# 'Package required for SPTnet.txt'  'Trained models'/
#  PSF-toolbox/                       transformer3d.py
#  __pycache__/                       transformer.py
#  README.md                          Visualize_SPTnet_Outputs_GUI.m
#  runscripts.ipynb                   Visualize_SPTnet_Outputs.m
#  Segementation/

# %%
import sys

# Add the specific directory where your package was found
pkg_path = '/usr/local/lib/python3.11/site-packages'
if pkg_path not in sys.path:
    sys.path.insert(0, pkg_path)

# %%
# !python SPTnet_training_colab.py --model-dir ./my_model_output --data ./my_training_data/*.mat
# Out:
# Traceback (most recent call last):
#   File "/content/SPTnet/SPTnet/SPTnet_training_colab.py", line 4, in <module>
#     import matplotlib
#   File "/usr/local/lib/python3.11/site-packages/matplotlib/__init__.py", line 1299, in <module>
#     rcParams['backend'] = os.environ.get('MPLBACKEND')
#     ~~~~~~~~^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/site-packages/matplotlib/__init__.py", line 774, in __setitem__
#     raise ValueError(f"Key {key}: {ve}") from None
# ValueError: Key backend: 'module://matplotlib_inline.backend_inline' is not a valid value for backend; supported values are ['gtk3agg', 'gtk3cairo', 'gtk4agg', 'gtk4cairo', 'macosx', 'nbagg', 'notebook', 'qtagg', 'qtcairo', 'qt5agg', 'qt5cairo', 'tkagg', 'tkcairo', 'webagg', 'wx', 'wxagg', 'wxcairo', 'agg', 'cairo', 'pdf', 'pgf', 'ps', 'svg', 'template']

# %%
import sys

# Add the specific directory where your package was found
pkg_path = '/usr/local/lib/python3.11/site-packages'
if pkg_path not in sys.path:
    sys.path.insert(0, pkg_path)

# Now try the import again
from positional_encodings.torch_encodings import PositionalEncodingPermute1D, PositionalEncodingPermute2D, PositionalEncodingPermute3D, Summer
print("Imports worked!")
# Out:
# Imports worked!

# %%
# !pip install positional-encodings
# Out:
# Requirement already satisfied: positional-encodings in /usr/local/lib/python3.11/site-packages (6.0.3)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/site-packages (from positional-encodings) (2.4.2)
